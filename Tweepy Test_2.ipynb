# %%
import tweepy
from tweepy import Stream
from tweepy.streaming import StreamListener
from tweepy import OAuthHandler
import pandas as pd
import numpy as np
import json
 
consumer_key = 'QMVyK39ZrZ7G6q8qECKx9zHjx'
consumer_secret = 'iOfdLzfdceYqZeI4XlbZPXruqSc1pWpA3hmcTCVpgLOlamvBDG'
access_token = '244792775-pQrpGYOLYn5OYW19Rv19X6hRC1zMNkwEzJZg13Kc'
access_secret = 'Ex7k9unZzrQ69NQvyhMJQkDvreWErkpzvNM5nGrQRCYqS'
 
auth = OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_secret)
 
api = tweepy.API(auth)

# %%
# https://youtu.be/wlnx-7cm4Gg?t=612

class TwitterStreamer():
    
    def stream_tweets(self, fetched_tweets_filename, hash_tag_list):
        
        listener = TwitterListener(fetched_tweets_filename)
        stream = Stream(auth, listener)
    
        stream.filter(track=hash_tag_list)

class TwitterListener(StreamListener):
    
    def __init__(self, fetched_tweets_filename):
        self.fetched_tweets_filename = fetched_tweets_filename

    def on_data(self, data):
        try:
            with open(self.fetched_tweets_filename, 'a') as f:
                f.write(data)
            return True
        except BaseException as e:
            print("Error on_data: %s" % str(e))
            
        return True         
 
    def on_error(self, status):
        if status == 420:
            # Return False on_data method in case rate limit is reached
            return False
        print(status)
        return True
    
if __name__ == "__main__":
    hash_tag_list = ["donald trump"]
    fetched_tweets_filename = "tweets.json"
    
    twitter_streamer = TwitterStreamer()
    twitter_streamer.stream_tweets(fetched_tweets_filename, hash_tag_list)
# Out:
# ---------------------------------------------------------------------------
# WantReadError                             Traceback (most recent call last)
# ~/anaconda3/envs/tf-gpu/lib/python3.6/site-packages/urllib3/contrib/pyopenssl.py in recv_into(self, *args, **kwargs)
#     293         try:
# --> 294             return self.connection.recv_into(*args, **kwargs)
#     295         except OpenSSL.SSL.SysCallError as e:
#
# ~/anaconda3/envs/tf-gpu/lib/python3.6/site-packages/OpenSSL/SSL.py in recv_into(self, buffer, nbytes, flags)
#    1821             result = _lib.SSL_read(self._ssl, buf, nbytes)
# -> 1822         self._raise_ssl_error(self._ssl, result)
#    1823
#
# ~/anaconda3/envs/tf-gpu/lib/python3.6/site-packages/OpenSSL/SSL.py in _raise_ssl_error(self, ssl, result)
#    1621         if error == _lib.SSL_ERROR_WANT_READ:
# -> 1622             raise WantReadError()
#    1623         elif error == _lib.SSL_ERROR_WANT_WRITE:
#
# WantReadError:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-24-03f5e43316f0> in <module>
#      42
#      43     twitter_streamer = TwitterStreamer()
# ---> 44     twitter_streamer.stream_tweets(fetched_tweets_filename, hash_tag_list)
#
# <ipython-input-24-03f5e43316f0> in stream_tweets(self, fetched_tweets_filename, hash_tag_list)
#      12         stream = Stream(auth, listener)
#      13
# ---> 14         stream.filter(track=hash_tag_list)
#      15
#      16 class TwitterListener(StreamListener):
#
# ~/anaconda3/envs/tf-gpu/lib/python3.6/site-packages/tweepy/streaming.py in filter(self, follow, track, async, locations, stall_warnings, languages, encoding, filter_level)
#     443         self.session.params = {'delimited': 'length'}
#     444         self.host = 'stream.twitter.com'
# --> 445         self._start(async)
#     446
#     447     def sitestream(self, follow, stall_warnings=False,
#
# ~/anaconda3/envs/tf-gpu/lib/python3.6/site-packages/tweepy/streaming.py in _start(self, async)
#     359             self._thread.start()
#     360         else:
# --> 361             self._run()
#     362
#     363     def on_closed(self, resp):
#
# ~/anaconda3/envs/tf-gpu/lib/python3.6/site-packages/tweepy/streaming.py in _run(self)
#     261                     self.snooze_time = self.snooze_time_step
#     262                     self.listener.on_connect()
# --> 263                     self._read_loop(resp)
#     264             except (Timeout, ssl.SSLError) as exc:
#     265                 # This is still necessary, as a SSLError can actually be
#
# ~/anaconda3/envs/tf-gpu/lib/python3.6/site-packages/tweepy/streaming.py in _read_loop(self, resp)
#     311             length = 0
#     312             while not resp.raw.closed:
# --> 313                 line = buf.read_line().strip()
#     314                 if not line:
#     315                     self.listener.keep_alive()  # keep-alive new lines are expected
#
# ~/anaconda3/envs/tf-gpu/lib/python3.6/site-packages/tweepy/streaming.py in read_line(self, sep)
#     177             else:
#     178                 start = len(self._buffer)
# --> 179             self._buffer += self._stream.read(self._chunk_size)
#     180
#     181     def _pop(self, length):
#
# ~/anaconda3/envs/tf-gpu/lib/python3.6/site-packages/urllib3/response.py in read(self, amt, decode_content, cache_content)
#     440             else:
#     441                 cache_content = False
# --> 442                 data = self._fp.read(amt)
#     443                 if amt != 0 and not data:  # Platform-specific: Buggy versions of Python.
#     444                     # Close the connection when no data is returned
#
# ~/anaconda3/envs/tf-gpu/lib/python3.6/http/client.py in read(self, amt)
#     447             # Amount is given, implement using readinto
#     448             b = bytearray(amt)
# --> 449             n = self.readinto(b)
#     450             return memoryview(b)[:n].tobytes()
#     451         else:
#
# ~/anaconda3/envs/tf-gpu/lib/python3.6/http/client.py in readinto(self, b)
#     481
#     482         if self.chunked:
# --> 483             return self._readinto_chunked(b)
#     484
#     485         if self.length is not None:
#
# ~/anaconda3/envs/tf-gpu/lib/python3.6/http/client.py in _readinto_chunked(self, b)
#     576         try:
#     577             while True:
# --> 578                 chunk_left = self._get_chunk_left()
#     579                 if chunk_left is None:
#     580                     return total_bytes
#
# ~/anaconda3/envs/tf-gpu/lib/python3.6/http/client.py in _get_chunk_left(self)
#     544                 self._safe_read(2)  # toss the CRLF at the end of the chunk
#     545             try:
# --> 546                 chunk_left = self._read_next_chunk_size()
#     547             except ValueError:
#     548                 raise IncompleteRead(b'')
#
# ~/anaconda3/envs/tf-gpu/lib/python3.6/http/client.py in _read_next_chunk_size(self)
#     504     def _read_next_chunk_size(self):
#     505         # Read the next chunk size from the file
# --> 506         line = self.fp.readline(_MAXLINE + 1)
#     507         if len(line) > _MAXLINE:
#     508             raise LineTooLong("chunk size")
#
# ~/anaconda3/envs/tf-gpu/lib/python3.6/socket.py in readinto(self, b)
#     584         while True:
#     585             try:
# --> 586                 return self._sock.recv_into(b)
#     587             except timeout:
#     588                 self._timeout_occurred = True
#
# ~/anaconda3/envs/tf-gpu/lib/python3.6/site-packages/urllib3/contrib/pyopenssl.py in recv_into(self, *args, **kwargs)
#     304                 raise
#     305         except OpenSSL.SSL.WantReadError:
# --> 306             if not util.wait_for_read(self.socket, self.socket.gettimeout()):
#     307                 raise timeout('The read operation timed out')
#     308             else:
#
# ~/anaconda3/envs/tf-gpu/lib/python3.6/site-packages/urllib3/util/wait.py in wait_for_read(sock, timeout)
#     141     Returns True if the socket is readable, or False if the timeout expired.
#     142     """
# --> 143     return wait_for_socket(sock, read=True, timeout=timeout)
#     144
#     145
#
# ~/anaconda3/envs/tf-gpu/lib/python3.6/site-packages/urllib3/util/wait.py in poll_wait_for_socket(sock, read, write, timeout)
#     102         return poll_obj.poll(t)
#     103
# --> 104     return bool(_retry_on_intr(do_poll, timeout))
#     105
#     106
#
# ~/anaconda3/envs/tf-gpu/lib/python3.6/site-packages/urllib3/util/wait.py in _retry_on_intr(fn, timeout)
#      40     # Modern Python, that retries syscalls by default
#      41     def _retry_on_intr(fn, timeout):
# ---> 42         return fn(timeout)
#      43 else:
#      44     # Old and broken Pythons.
#
# ~/anaconda3/envs/tf-gpu/lib/python3.6/site-packages/urllib3/util/wait.py in do_poll(t)
#     100         if t is not None:
#     101             t *= 1000
# --> 102         return poll_obj.poll(t)
#     103
#     104     return bool(_retry_on_intr(do_poll, timeout))
#
# KeyboardInterrupt:

# %%
# load tweets from json into a pandas datafram

tweets = []
for line in open('tweets.json', 'r'):
    tweets.append(json.loads(line))

# %%
df = pd.DataFrame(tweets)
df.head()
# Out:
#   contributors coordinates                      created_at display_text_range  \
# 0         None        None  Mon Mar 04 19:11:26 +0000 2019                NaN
# 1         None        None  Mon Mar 04 19:11:26 +0000 2019                NaN
# 2         None        None  Mon Mar 04 19:11:26 +0000 2019                NaN
# 3         None        None  Mon Mar 04 19:11:26 +0000 2019                NaN
# 4         None        None  Mon Mar 04 19:11:27 +0000 2019                NaN
#
#                                             entities  \
# 0  {'hashtags': [], 'urls': [{'url': 'https://t.c...
# 1  {'hashtags': [], 'urls': [], 'user_mentions': ...
# 2  {'hashtags': [], 'urls': [], 'user_mentions': ...
# 3  {'hashtags': [], 'urls': [], 'user_mentions': ...
# 4  {'hashtags': [], 'urls': [], 'user_mentions': ...
#
#                                    extended_entities extended_tweet  \
# 0                                                NaN            NaN
# 1                                                NaN            NaN
# 2  {'media': [{'id': 1102593090563518464, 'id_str...            NaN
# 3                                                NaN            NaN
# 4                                                NaN            NaN
#
#    favorite_count  favorited filter_level  ...  \
# 0               0      False          low  ...
# 1               0      False          low  ...
# 2               0      False          low  ...
# 3               0      False          low  ...
# 4               0      False          low  ...
#
#                              quoted_status_permalink  reply_count  \
# 0                                                NaN            0
# 1                                                NaN            0
# 2                                                NaN            0
# 3  {'url': 'https://t.co/lcpkgECyHc', 'expanded':...            0
# 4  {'url': 'https://t.co/gfUFz9VW4Y', 'expanded':...            0
#
#   retweet_count retweeted                                   retweeted_status  \
# 0             0     False                                                NaN
# 1             0     False  {'created_at': 'Mon Mar 04 18:48:38 +0000 2019...
# 2             0     False  {'created_at': 'Mon Mar 04 15:34:44 +0000 2019...
# 3             0     False                                                NaN
# 4             0     False  {'created_at': 'Mon Mar 04 16:53:06 +0000 2019...
#
#                                               source  \
# 0  <a href="http://twitter.com/download/android" ...
# 1  <a href="http://twitter.com" rel="nofollow">Tw...
# 2  <a href="http://twitter.com/download/iphone" r...
# 3  <a href="http://twitter.com" rel="nofollow">Tw...
# 4  <a href="http://twitter.com/download/android" ...
#
#                                                 text   timestamp_ms  \
# 0  Breaking News! Ambazonia: An Envoy of Donald T...  1551726686506
# 1  RT @PalmerReport: Donald Trump’s day so far:\n...  1551726686649
# 2  RT @Rob_Flaherty: donald trump thinks only peo...  1551726686634
# 3                             Hamberders, part deux.  1551726686660
# 4  RT @tedlieu: Unlike last term, the House Judic...  1551726687053
#
#    truncated                                               user
# 0      False  {'id': 1088094936753496065, 'id_str': '1088094...
# 1      False  {'id': 290824795, 'id_str': '290824795', 'name...
# 2      False  {'id': 381283635, 'id_str': '381283635', 'name...
# 3      False  {'id': 844969907339055108, 'id_str': '84496990...
# 4      False  {'id': 829560141330538496, 'id_str': '82956014...
#
# [5 rows x 36 columns]

# %%
df.loc[:,'text']
# Out:
# 0     Breaking News! Ambazonia: An Envoy of Donald T...
# 1     RT @PalmerReport: Donald Trump’s day so far:\n...
# 2     RT @Rob_Flaherty: donald trump thinks only peo...
# 3                                Hamberders, part deux.
# 4     RT @tedlieu: Unlike last term, the House Judic...
# 5     RT @RedNationRising: "Donald Trump wants to di...
# 6     RT @MacMillerMemoir: The “Donald Trump” music ...
# 7     RT @JaneMayerNYer: New from me: Fox News HAD t...
# 8     RT @pattymo: Stunned beyond belief by these re...
# 9     RT @tedlieu: Dear @NRA: Hi. https://t.co/5HfSa...
# 10    RT @nowthisnews: Sen. @BernieSanders got perso...
# 11    RT @RedaMor_: NEW: Democrats demand from the W...
# 12    @mitchellvii It’s not as though Donald Trump g...
# 13    RT @PalmerReport: Donald Trump slips up and ma...
# 14    RT @HLAurora63: Millions left over from the la...
# 15    RT @JaneMayerNYer: New from me: Fox News HAD t...
# 16    Donald J. Trump will be our POTUS until noon o...
# 17    RT @1Romans58: This will all come to a halt on...
# 18    RT @tedlieu: Unlike last term, the House Judic...
# 19    Donald, you’re killing unborn babies..\n@GOP @...
# 20    RT @American_Cori: I watched the young DJT on ...
# 21    RT @joncoopertweets: The House Judiciary Commi...
# 22    RT @HouseIntel: BREAKING: @HouseIntel, @HouseF...
# 23    RT @nowthisnews: Sen. @BernieSanders got perso...
# 24    RT @WendySiegelman: Document Request Monday:\n...
# 25    RT @politico: Rep. Alexandria Ocasio-Cortez sa...
# 26    RT @RedNationRising: "Donald Trump wants to di...
# 27    RT @tedlieu: Unlike last term, the House Judic...
# 28    RT @tedlieu: Unlike last term, the House Judic...
# 29    RT @business: House Judiciary Chairman Jerrold...
#                             ...
# 55    RT @WendySiegelman: Document Request Monday:\n...
# 56    RT @DeanObeidallah: The impeachment of Donald ...
# 57    RT @middleageriot: Harry Truman: "The buck sto...
# 58    RT @jilevin: Donald Trump Could '150 Percent' ...
# 59    RT @CNNPolitics: See the full list of names re...
# 60    RT @tedlieu: Unlike last term, the House Judic...
# 61    RT @leahmcelrath: Includes Cambridge Analytica...
# 62    @TheRynheart @senatemajldr When the time comes...
# 63    RT @mgrant76308: ESCALATING: Democrats expand ...
# 64    RT @shannonrwatts: BREAKING: The House Judicia...
# 65    RT @HouseIntel: BREAKING: @HouseIntel, @HouseF...
# 66    RT @JaneMayerNYer: New from me: Fox News HAD t...
# 67    a police officer meets a old friend at a cruis...
# 68    RT @PalmerReport: It’s all over for Donald Tru...
# 69    RT @PalmerReport: Donald Trump’s day so far:\n...
# 70    RT @tedlieu: Unlike last term, the House Judic...
# 71    RT @TheLastRefuge2: 🤔Senate Majority Leader Ha...
# 72    RT @AshaRangappa_: So far, Trump got help winn...
# 73    RT @not_gray_: All I’m saying is that I’ve nev...
# 74    RT @PalmerReport: Donald Trump’s day so far:\n...
# 75    RT @AshaRangappa_: So far, Trump got help winn...
# 76    RT @HouseIntel: BREAKING: @HouseIntel, @HouseF...
# 77    Does CNNi news ever report anything other than...
# 78    RT @VanityFair: “You only became an executive ...
# 79    RT @PalmerReport: Donald Trump’s day of reckon...
# 80    RT @tedlieu: Unlike last term, the House Judic...
# 81    "Donald Trump es enemigo del pueblo estadounid...
# 82    RT @MrsMalindo: @boxersforlife @Newsweek I was...
# 83    RT @JaneMayerNYer: New from me: Fox News HAD t...
# 84    RT @tedlieu: Dear @NRA: Hi. https://t.co/5HfSa...
# Name: text, Length: 85, dtype: object

# %%
# Out:
# pandas.core.series.Series

# %%
# Used to stream tweets and download into JSON file -- only gives text. Not good format
class MyListener(StreamListener):
 
    def on_status(self, status):
        try:
            with open('happy.json', 'a') as f:
                f.write(status.text)
                return True
        except BaseException as e:
            print("Error on_data: %s" % str(e))
        return True
 
    def on_error(self, status):
        print(status)
        return True
 
twitter_stream = Stream(auth, MyListener())
twitter_stream.filter(track=['donald trump'])
# Out:
# ---------------------------------------------------------------------------
# WantReadError                             Traceback (most recent call last)
# ~/anaconda3/envs/tf-gpu/lib/python3.6/site-packages/urllib3/contrib/pyopenssl.py in recv_into(self, *args, **kwargs)
#     293         try:
# --> 294             return self.connection.recv_into(*args, **kwargs)
#     295         except OpenSSL.SSL.SysCallError as e:
#
# ~/anaconda3/envs/tf-gpu/lib/python3.6/site-packages/OpenSSL/SSL.py in recv_into(self, buffer, nbytes, flags)
#    1821             result = _lib.SSL_read(self._ssl, buf, nbytes)
# -> 1822         self._raise_ssl_error(self._ssl, result)
#    1823
#
# ~/anaconda3/envs/tf-gpu/lib/python3.6/site-packages/OpenSSL/SSL.py in _raise_ssl_error(self, ssl, result)
#    1621         if error == _lib.SSL_ERROR_WANT_READ:
# -> 1622             raise WantReadError()
#    1623         elif error == _lib.SSL_ERROR_WANT_WRITE:
#
# WantReadError:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-9-5b5c27aa2e04> in <module>
#      16
#      17 twitter_stream = Stream(auth, MyListener())
# ---> 18 twitter_stream.filter(track=['donald trump'])
#
# ~/anaconda3/envs/tf-gpu/lib/python3.6/site-packages/tweepy/streaming.py in filter(self, follow, track, async, locations, stall_warnings, languages, encoding, filter_level)
#     443         self.session.params = {'delimited': 'length'}
#     444         self.host = 'stream.twitter.com'
# --> 445         self._start(async)
#     446
#     447     def sitestream(self, follow, stall_warnings=False,
#
# ~/anaconda3/envs/tf-gpu/lib/python3.6/site-packages/tweepy/streaming.py in _start(self, async)
#     359             self._thread.start()
#     360         else:
# --> 361             self._run()
#     362
#     363     def on_closed(self, resp):
#
# ~/anaconda3/envs/tf-gpu/lib/python3.6/site-packages/tweepy/streaming.py in _run(self)
#     261                     self.snooze_time = self.snooze_time_step
#     262                     self.listener.on_connect()
# --> 263                     self._read_loop(resp)
#     264             except (Timeout, ssl.SSLError) as exc:
#     265                 # This is still necessary, as a SSLError can actually be
#
# ~/anaconda3/envs/tf-gpu/lib/python3.6/site-packages/tweepy/streaming.py in _read_loop(self, resp)
#     311             length = 0
#     312             while not resp.raw.closed:
# --> 313                 line = buf.read_line().strip()
#     314                 if not line:
#     315                     self.listener.keep_alive()  # keep-alive new lines are expected
#
# ~/anaconda3/envs/tf-gpu/lib/python3.6/site-packages/tweepy/streaming.py in read_line(self, sep)
#     177             else:
#     178                 start = len(self._buffer)
# --> 179             self._buffer += self._stream.read(self._chunk_size)
#     180
#     181     def _pop(self, length):
#
# ~/anaconda3/envs/tf-gpu/lib/python3.6/site-packages/urllib3/response.py in read(self, amt, decode_content, cache_content)
#     440             else:
#     441                 cache_content = False
# --> 442                 data = self._fp.read(amt)
#     443                 if amt != 0 and not data:  # Platform-specific: Buggy versions of Python.
#     444                     # Close the connection when no data is returned
#
# ~/anaconda3/envs/tf-gpu/lib/python3.6/http/client.py in read(self, amt)
#     447             # Amount is given, implement using readinto
#     448             b = bytearray(amt)
# --> 449             n = self.readinto(b)
#     450             return memoryview(b)[:n].tobytes()
#     451         else:
#
# ~/anaconda3/envs/tf-gpu/lib/python3.6/http/client.py in readinto(self, b)
#     481
#     482         if self.chunked:
# --> 483             return self._readinto_chunked(b)
#     484
#     485         if self.length is not None:
#
# ~/anaconda3/envs/tf-gpu/lib/python3.6/http/client.py in _readinto_chunked(self, b)
#     576         try:
#     577             while True:
# --> 578                 chunk_left = self._get_chunk_left()
#     579                 if chunk_left is None:
#     580                     return total_bytes
#
# ~/anaconda3/envs/tf-gpu/lib/python3.6/http/client.py in _get_chunk_left(self)
#     544                 self._safe_read(2)  # toss the CRLF at the end of the chunk
#     545             try:
# --> 546                 chunk_left = self._read_next_chunk_size()
#     547             except ValueError:
#     548                 raise IncompleteRead(b'')
#
# ~/anaconda3/envs/tf-gpu/lib/python3.6/http/client.py in _read_next_chunk_size(self)
#     504     def _read_next_chunk_size(self):
#     505         # Read the next chunk size from the file
# --> 506         line = self.fp.readline(_MAXLINE + 1)
#     507         if len(line) > _MAXLINE:
#     508             raise LineTooLong("chunk size")
#
# ~/anaconda3/envs/tf-gpu/lib/python3.6/socket.py in readinto(self, b)
#     584         while True:
#     585             try:
# --> 586                 return self._sock.recv_into(b)
#     587             except timeout:
#     588                 self._timeout_occurred = True
#
# ~/anaconda3/envs/tf-gpu/lib/python3.6/site-packages/urllib3/contrib/pyopenssl.py in recv_into(self, *args, **kwargs)
#     304                 raise
#     305         except OpenSSL.SSL.WantReadError:
# --> 306             if not util.wait_for_read(self.socket, self.socket.gettimeout()):
#     307                 raise timeout('The read operation timed out')
#     308             else:
#
# ~/anaconda3/envs/tf-gpu/lib/python3.6/site-packages/urllib3/util/wait.py in wait_for_read(sock, timeout)
#     141     Returns True if the socket is readable, or False if the timeout expired.
#     142     """
# --> 143     return wait_for_socket(sock, read=True, timeout=timeout)
#     144
#     145
#
# ~/anaconda3/envs/tf-gpu/lib/python3.6/site-packages/urllib3/util/wait.py in poll_wait_for_socket(sock, read, write, timeout)
#     102         return poll_obj.poll(t)
#     103
# --> 104     return bool(_retry_on_intr(do_poll, timeout))
#     105
#     106
#
# ~/anaconda3/envs/tf-gpu/lib/python3.6/site-packages/urllib3/util/wait.py in _retry_on_intr(fn, timeout)
#      40     # Modern Python, that retries syscalls by default
#      41     def _retry_on_intr(fn, timeout):
# ---> 42         return fn(timeout)
#      43 else:
#      44     # Old and broken Pythons.
#
# ~/anaconda3/envs/tf-gpu/lib/python3.6/site-packages/urllib3/util/wait.py in do_poll(t)
#     100         if t is not None:
#     101             t *= 1000
# --> 102         return poll_obj.poll(t)
#     103
#     104     return bool(_retry_on_intr(do_poll, timeout))
#
# KeyboardInterrupt:

# %%
# Used to stream tweets and download into JSON file
class MyListener(StreamListener):
 
    def on_data(self, data):
        try:
            with open('happy.json', 'a') as f:
                f.write(data)
                return True
        except BaseException as e:
            print("Error on_data: %s" % str(e))
        return True
 
    def on_error(self, status):
        print(status)
        return True
 
twitter_stream = Stream(auth, MyListener())
twitter_stream.filter(track=['donald trump'])
